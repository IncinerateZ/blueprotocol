# %%
import matplotlib.pyplot as plt

x = [-20,-9468,-9483,-18197,-17634,-26749,-16392,-30450,4715]
y = [-16421,-15353,-6593,2071,11642,-2494,-22289,-18945,-2717]

plt.scatter(0.001,0.001, c="red")
plt.scatter(x[0],y[0], c="blue")
plt.scatter(x[1],y[1], c="blue")
plt.scatter(x[2],y[2], c="blue")
plt.scatter(x[3],y[3], c="blue")
plt.scatter(x[4],y[4], c="blue")
plt.scatter(x[5],y[5], c="blue")
plt.scatter(x[6],y[6], c="blue")
plt.scatter(x[7],y[7], c="blue")
plt.scatter(x[8],y[8], c="blue")

plt.show()

# %%
def convert_coordinates(initial_coordinates):
    x, y = initial_coordinates
    desired_x = (x + 18200) / 1000
    desired_y = (-y - 2000) / 1000
    return (desired_x, desired_y)

convert_coordinates((x[5], y[5]))
# Out:
# (-8.549, 0.494)

# %%
vals = [-0.0014201327568357592, -0.0013293818797629128, -0.0009601092067344153, -0.0020956059874456786, -0.0010719807593197045, -0.0002566158781074579, -0.0016810982996096728, -0.001558722618105041, -0.0005704821494295179]

s = 0

for v in vals:
    s += v

print('avg: ' + str(s / len(vals)))
# Out:
# avg: -0.0012160143928166844

# %%
21.580296858773778 - -0.2718858147938131
# Out:
# 21.85218267356759

# %%
57.05181095429502 - 75.54385998767125
# Out:
# -18.492049033376233

# %%
57.05181095429502 / -6593
# Out:
# -0.008653391620551346

# %%
39.90912433991871 / -16421
# Out:
# -0.002430371130864059

# %%
62.537136147609544 / -2494
# Out:
# -0.025075034541944485

# %%
26.409090846154463 / -22289
# Out:
# -0.0011848486179799212

# %%
75.54385998767125 / 11642
# Out:
# 0.0064889074031670895

# %%
-0.0011848486179799212
-0.002430371130864059
-0.008653391620551346
-0.025075034541944485
0.0064889074031670895
# Out:
# 0.0064889074031670895

# %%
import math

def f(y):
    return ((-5.715 * math.pow(10, -11) * math.pow(y, 4)) + (1.926 * math.pow(10, -7) * math.pow(y, 3)) - (2.462 * math.pow(10, -4) * math.pow(y, 2)) - (0.1024 * y) - 0.5157)

# %%
f(-2494)
# Out:
# -6475.330077728467

# %%
def f2(y):
    return (-6.695 * math.pow(10, -6) * y) - 0.223

# %%
f2(-6593)
# Out:
# -0.178859865

# %%
ds = [
    (-22289, -0.0011848486179799212),
(-16421, -0.002430371130864059),
(-6593, -0.008653391620551346),
(-2494, -0.025075034541944485),
(11642, 0.0064889074031670895),
(2071, 0.03263)
]

# %%
for d in ds:
    plt.scatter(d[0], d[1])

# %%
ox = -179.9769573591043
oy = -21.956404023496283

xscale = 0.18748409442728267
yscale = 0.09911743935461076

def tr(x, y):
    return (x - -84960.0) / 70, (y - -34580.0) / 70

im = plt.imread('./1.png')
plt.imshow(im)

for i in range(len(x)):
    x_ = x[i]
    y_ = y[i]
    x_, y_ = tr(x_, y_)
    # x_ *= xscale
    # y_ *= yscale
    plt.scatter(x_, 1080 - y_ - 100)
plt.scatter(0.001, 0.001, c="black")
